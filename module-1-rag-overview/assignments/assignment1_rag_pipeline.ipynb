# %% [markdown]
# # Assignment 1: Mi Primer Pipeline RAG
#
# En este assignment construirás tu primer sistema RAG completo usando
# un dataset real de noticias de BBC del año 2024.
#
# ## ¿Por qué 2024?
# El modelo que usamos fue entrenado hasta diciembre 2023.
# No sabe nada de lo que pasó en 2024.
# Con RAG le inyectamos noticias reales de 2024 para que pueda
# responder preguntas sobre eventos recientes.
#
# ## ¿Qué construirás?
# Un pipeline completo de 4 pasos:
#
# 1. `retrieve()` → encuentra los índices de noticias relevantes
# 2. `query_news()` → trae las noticias por índice
# 3. `get_relevant_data()` → combina los dos pasos anteriores ← **TÚ LO IMPLEMENTAS**
# 4. `format_relevant_data()` → convierte las noticias a texto legible ← **TÚ LO IMPLEMENTAS**
#
# ---
#
# ## Tabla de Contenidos
# - [1 - Introducción y arquitectura RAG](#1)
# - [2 - Cargando el dataset](#2)
# - [3 - Funciones principales](#3)
#     - [3.1 query_news — consultar por índice](#3-1)
#     - [3.2 retrieve — encontrar noticias relevantes](#3-2)
#     - [3.3 get_relevant_data — Ejercicio 1](#3-3)
#     - [3.4 format_relevant_data — Ejercicio 2](#3-4)
#     - [3.5 generate_final_prompt](#3-5)
#     - [3.6 Llamada al LLM](#3-6)
# - [4 - Experimentando con tu sistema RAG](#4)

# %%
import sys
sys.path.insert(0, '/Users/admin/gianpc/projects/DeepLearningAI/rag-deeplearning-ai/module-1-rag-overview/assignments/')

from utils import (
    retrieve,
    pprint,
    generate_with_single_input,
    read_dataframe
)
